# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('pred_lstm18.csv')
dataset_2019 = pd.read_csv('pred_lstm19.csv')
dist = pd.read_csv('dataset/Distance_Matrix.csv')
dist.drop(columns="Unnamed: 0")
# Out:
#              0         1         2         3         4         5         6  \
# 0       0.0000   11.3769   20.4557   38.1227   45.3810   54.9915   78.6108
# 1      11.3769    0.0000    9.0788   28.9141   36.1724   45.7829   69.4022
# 2      20.4557    9.0788    0.0000   22.3791   29.6374   39.2478   62.8671
# 3      38.1227   28.9141   22.3791    0.0000   11.8343   23.5413   41.8396
# 4      45.3810   36.1724   29.6374   11.8343    0.0000   11.7070   24.3986
# ...        ...       ...       ...       ...       ...       ...       ...
# 2413  671.2005  668.9528  669.5556  669.9084  652.1102  640.4032  627.7116
# 2414  663.4455  661.1978  661.8006  662.1534  644.3551  632.6481  619.9566
# 2415  663.7748  661.5271  662.1298  662.4826  644.6844  632.9774  620.2859
# 2416  671.0165  668.7688  669.3715  669.7244  651.9261  640.2191  627.5276
# 2417  679.2328  676.9851  677.5878  677.9406  660.1424  648.4354  635.7439
#
#              7         8         9  ...      2408      2409      2410  \
# 0     118.6750  102.6639  113.4309  ...  683.8771  687.6310  697.3246
# 1      78.2329   93.4553  111.1832  ...  681.6295  685.3833  695.0769
# 2      71.6979   86.9203  111.7859  ...  682.2323  685.9861  695.6796
# 3      50.6703   65.8927   82.5852  ...  681.4226  685.1765  694.8701
# 4      33.2293   53.9901   65.1442  ...  663.9816  667.7355  677.4291
# ...        ...       ...       ...  ...       ...       ...       ...
# 2413  622.9663  638.9532  617.7221  ...  109.0007  112.7545  122.4481
# 2414  615.2112  631.1981  609.9671  ...  101.2456  104.9995  114.6931
# 2415  615.5405  631.5274  610.2964  ...   84.1469   87.9008   97.5943
# 2416  622.7822  638.7691  617.5381  ...   91.3886   95.1425  104.8361
# 2417  630.9985  646.9854  625.7544  ...   99.6049  103.3587  113.0523
#
#           2411      2412      2413      2414      2415      2416      2417
# 0     669.3962  667.6788  665.5775  662.0291  665.9655  673.2073  681.4235
# 1     667.1485  665.4311  663.3298  659.7815  663.7178  670.9596  679.1758
# 2     667.7513  666.0339  663.9326  660.3843  664.3206  671.5623  679.7786
# 3     666.9417  665.2243  663.1230  659.5746  663.5110  670.7528  678.9690
# 4     649.5007  647.7833  645.6820  642.1336  646.0700  653.3118  661.5280
# ...        ...       ...       ...       ...       ...       ...       ...
# 2413   12.3091    9.1558    0.0000   14.5629   22.3860   36.6284   44.8446
# 2414   26.4955   23.3422   14.1864    0.0000   14.5984   28.8407   37.0570
# 2415   34.3098   31.1565   22.0007   12.8105    0.0000   14.2423   22.4586
# 2416   48.5521   45.3988   36.2430   27.0528   14.2423    0.0000   12.4741
# 2417   56.7684   53.6151   44.4593   35.2691   22.4586   12.4741    0.0000
#
# [2418 rows x 2418 columns]

# %%
arr = [i[0] for i in dataset.values]
arr1 = [i[0] for i in dataset_2019.values]
arr2 = [min(arr[i], arr1[i]) for i in range(len(arr))]

print(sum(arr1), sum(arr), sum(arr2))
# Out:
# 336415.76609212795 348012.75765273994 284027.8982988337

# %%
sad = [list(i) for i in list(dist.values)]

# %%
min(arr)
# Out:
# 0.53026325

# %%
from pulp import *
import random as rnd

sites = [f"Site_{i}" for i in range(300)]
depots = [f"{i}" for i in range(300)]

supply = {f"Site_{i}":arr[i] for i in range(300)}
supply_2019 = {f"Site_{i}":arr1[i] for i in range(300)}

refineries = [f"{i}" for i in range(300)]

demand = {f"{i}":19999.99 for i in range(300)}
demand_ref = {f"{i}":99999.99 for i in range(300)}

sad = [list(i) for i in list(dist.values)]
distance = sad
distance = makeDict([sites, depots], distance, 0)

prob = LpProblem("Depot_Problem", LpMinimize)

Routes = [(w, b) for w in sites for b in depots]

depot_var = LpVariable.dicts("Supply_to_depots",depots, 0, 1, LpInteger)

vars = LpVariable.dicts("Route", (sites, depots), 0, None, LpInteger)

# Ref
ref_vars = LpVariable.dicts("Route_ref", (depots, refineries), 0, None, LpInteger)
ref_var = LpVariable.dicts("Supply_to_refineries",refineries, 0, 1, LpInteger)
Routes_ref = [(w, b) for w in depots for b in refineries]

main_obj = (lpSum(vars[w][b] * distance[w][b] for (w, b) in Routes)*0.001)
ref_constraint = (lpSum(ref_vars[b][k] * distance[b][k] for (b, k) in Routes_ref)*0.001)

prob += ref_constraint + main_obj

for w in sites:
    prob += (
        lpSum(vars[w][b] for b in depots) <= supply[w],
        f"Sites must not give more than they produce{w}"
    )

#Refineries
for b in depots:
    prob += (
        lpSum(ref_vars[b][k] for k in refineries) <= (lpSum(vars[w][b] for w in sites)),
        f"Depot must not give more than they produce{b}"
    )

for b in depots:
    prob += (
        lpSum([vars[w][b] for w in sites]) <= demand[b]*depot_var[b],
        f"Sum of products into depot should be less than its capacity {b}"
    )

#Refineries
for b in refineries:
    prob += (
        lpSum([ref_vars[j][b] for j in depots]) <= demand_ref[b]*ref_var[b],
        f"Sum of products into refineries should be less than its capacity {b}"
    )

prob += lpSum(depot_var[b] for b in depots) <= max(1, min(25,(0.8*sum(supply.values())//20000)+1))
prob += lpSum(depot_var[b] for b in depots) <= max(1, min(25,(0.8*sum(supply_2019.values())//20000)+1))
prob += lpSum(ref_var[b] for b in refineries) <= max(1, min(5,(0.8*sum(supply.values())//100000)+1))
prob += lpSum(ref_var[b] for b in refineries) <= max(1, min(5,(0.8*sum(supply_2019.values())//100000)+1))

huf = ()
for w in sites:
    for b in depots:
        if depot_var[b] >= 1:
            huf += (
            lpSum(vars[w][b] )
            )

prob += lpSum(huf) >= sum(supply.values())*0.8
prob += lpSum(huf) >= sum(supply_2019.values())*0.8

# Contraint 8: Amount entering into depot equals amount exiting depot
for b in depots:
    if depot_var[b] >= 1:
        prob += (
            lpSum(vars[w][b] for w in sites) <= lpSum(ref_vars[b][k] for k in refineries if ref_var[k] >= 1)
        )
    
# Refineries
hufe = ()
for w in depots:
    for b in refineries:
        if ref_var[b] >= 1:
            hufe += (
            lpSum(ref_vars[w][b] )
            )

prob += lpSum(hufe) >= sum(supply.values())*0.8
prob += lpSum(hufe) >= sum(supply_2019.values())*0.8

solver_options = {'msg': True, 'timeLimit': 1500}  # Set solver-specific options
prob.solve(CPLEX_CMD(**solver_options))

# for i in vars:
#     for each in vars[i]:
#         if vars[i][each].varValue > 0:
#             print(f"TP {vars[i][each]} ---  {vars[i][each].varValue}")
# print("\nSupply ref ")
# for i in ref_vars:
#     for each in ref_vars[i]:
#         if ref_vars[i][each].varValue > 0:
#             print(f"TP {ref_vars[i][each]} ---  {ref_vars[i][each].varValue}")
            
print("Supplied Depots:")
for b in depots:
    if depot_var[b].varValue == 1:
        print(b)

print("\nSupplied Refineries:")
for b in refineries:
    if ref_var[b].varValue == 1:
        print(b)

print(f"\n{sum(supply.values())}")
print((sum(supply.values())//20000)+1)
print(sum([(lpSum(vars[w][b].varValue for w in sites)) for b in depots if depot_var[b].varValue >= 1]))
print(sum([(lpSum(ref_vars[w][b].varValue for w in depots)) for b in refineries if ref_var[b].varValue >= 1]))
# print([depot_var[i].varValue for i in depot_var if depot_var[i] == 1])
# print(supply.values())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [49], line 99
#      96 prob += lpSum(hufe) >= sum(supply_2019.values())*0.8
#      98 solver_options = {'msg': True, 'timeLimit': 1500}  # Set solver-specific options
# ---> 99 prob.solve(CPLEX_CMD(**solver_options))
#     101 # for i in vars:
#     102 #     for each in vars[i]:
#     103 #         if vars[i][each].varValue > 0:
#    (...)
#     108 #         if ref_vars[i][each].varValue > 0:
#     109 #             print(f"TP {ref_vars[i][each]} ---  {ref_vars[i][each].varValue}")
#     111 print("Supplied Depots:")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pulp\pulp.py:1913, in LpProblem.solve(self, solver, **kwargs)
#    1911 # time it
#    1912 self.startClock()
# -> 1913 status = solver.actualSolve(self, **kwargs)
#    1914 self.stopClock()
#    1915 self.restoreObjective(wasNone, dummyVar)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pulp\apis\cplex_api.py:135, in CPLEX_CMD.actualSolve(self, lp)
#     133 cplex_cmds += "quit\n"
#     134 cplex_cmds = cplex_cmds.encode("UTF-8")
# --> 135 cplex.communicate(cplex_cmds)
#     136 if cplex.returncode != 0:
#     137     raise PulpSolverError("PuLP: Error while trying to execute " + self.path)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1126, in Popen.communicate(self, input, timeout)
#    1124         stderr = self.stderr.read()
#    1125         self.stderr.close()
# -> 1126     self.wait()
#    1127 else:
#    1128     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1189, in Popen.wait(self, timeout)
#    1187     endtime = _time() + timeout
#    1188 try:
# -> 1189     return self._wait(timeout=timeout)
#    1190 except KeyboardInterrupt:
#    1191     # https://bugs.python.org/issue25942
#    1192     # The first keyboard interrupt waits briefly for the child to
#    1193     # exit under the common assumption that it also received the ^C
#    1194     # generated SIGINT and will exit rapidly.
#    1195     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1470, in Popen._wait(self, timeout)
#    1467     timeout_millis = int(timeout * 1000)
#    1468 if self.returncode is None:
#    1469     # API note: Returns immediately if timeout_millis == 0.
# -> 1470     result = _winapi.WaitForSingleObject(self._handle,
#    1471                                          timeout_millis)
#    1472     if result == _winapi.WAIT_TIMEOUT:
#    1473         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
([(lpSum(vars[w][b].varValue for w in sites)) for b in depots if depot_var[b].varValue >= 1])
# Out:
# [12562.0, 14550.0, 16100.0]

# %%
dist.values[0][1]
# Out:
# 0.0

# %%
for i in vars:
    for each in vars[i]:
        if vars[i][each].varValue > 0:
            print(f"TP {vars[i][each]} ---  {vars[i][each].varValue}")
# Out:
# TP Route_Site_0_0 ---  8.0
# TP Route_Site_1_0 ---  29.0
# TP Route_Site_2_1 ---  62.0
# TP Route_Site_3_1 ---  80.0
# TP Route_Site_4_1 ---  20.0
# TP Route_Site_5_1 ---  31.0
# TP Route_Site_6_1 ---  38.0
# TP Route_Site_10_0 ---  16.0
# TP Route_Site_11_0 ---  3.0
# TP Route_Site_12_0 ---  2.0
# TP Route_Site_14_0 ---  1.0
# TP Route_Site_15_0 ---  63.0
# TP Route_Site_16_0 ---  85.0
# TP Route_Site_17_0 ---  159.0
# TP Route_Site_18_0 ---  135.0
# TP Route_Site_19_0 ---  90.0
# TP Route_Site_20_0 ---  116.0
# TP Route_Site_21_0 ---  118.0
# TP Route_Site_22_0 ---  148.0
# TP Route_Site_23_0 ---  172.0
# TP Route_Site_24_0 ---  171.0
# TP Route_Site_25_0 ---  68.0
# TP Route_Site_26_0 ---  56.0
# TP Route_Site_27_1 ---  40.0
# TP Route_Site_28_1 ---  6.0
# TP Route_Site_30_1 ---  35.0
# TP Route_Site_31_1 ---  130.0
# TP Route_Site_32_1 ---  170.0
# TP Route_Site_33_1 ---  124.0
# TP Route_Site_34_1 ---  153.0
# TP Route_Site_35_1 ---  165.0
# TP Route_Site_36_1 ---  156.0
# TP Route_Site_37_1 ---  172.0
# TP Route_Site_38_1 ---  98.0
# TP Route_Site_39_1 ---  82.0
# TP Route_Site_40_1 ---  54.0
# TP Route_Site_41_1 ---  91.0
# TP Route_Site_42_1 ---  128.0
# TP Route_Site_43_1 ---  41.0
# TP Route_Site_44_1 ---  2.0
# TP Route_Site_47_1 ---  26.0
# TP Route_Site_48_1 ---  131.0
# TP Route_Site_49_1 ---  114.0
# TP Route_Site_50_1 ---  130.0
# TP Route_Site_51_1 ---  155.0
# TP Route_Site_52_1 ---  163.0
# TP Route_Site_53_1 ---  146.0
# TP Route_Site_54_1 ---  190.0
# TP Route_Site_55_1 ---  143.0
# TP Route_Site_56_1 ---  147.0
# TP Route_Site_57_1 ---  127.0
# TP Route_Site_58_1 ---  125.0
# TP Route_Site_59_1 ---  72.0
# TP Route_Site_60_1 ---  76.0
# TP Route_Site_61_1 ---  12.0
# TP Route_Site_62_1 ---  8.0
# TP Route_Site_63_1 ---  22.0
# TP Route_Site_64_1 ---  9.0
# TP Route_Site_65_1 ---  3.0
# TP Route_Site_66_1 ---  5.0
# TP Route_Site_69_1 ---  7.0
# TP Route_Site_70_1 ---  103.0
# TP Route_Site_71_1 ---  117.0
# TP Route_Site_72_1 ---  133.0
# TP Route_Site_73_1 ---  198.0
# TP Route_Site_74_1 ---  173.0
# TP Route_Site_75_1 ---  211.0
# TP Route_Site_76_1 ---  174.0
# TP Route_Site_77_1 ---  100.0
# TP Route_Site_78_1 ---  165.0
# TP Route_Site_100_0 ---  148.0
# TP Route_Site_101_0 ---  202.0
# TP Route_Site_102_0 ---  151.0
# TP Route_Site_103_0 ---  117.0
# TP Route_Site_104_0 ---  176.0
# TP Route_Site_105_0 ---  173.0
# TP Route_Site_106_0 ---  135.0
# TP Route_Site_107_0 ---  68.0
# TP Route_Site_108_0 ---  5.0
# TP Route_Site_109_0 ---  13.0
# TP Route_Site_110_0 ---  11.0
# TP Route_Site_111_0 ---  4.0
# TP Route_Site_112_0 ---  12.0
# TP Route_Site_113_0 ---  34.0
# TP Route_Site_114_0 ---  20.0
# TP Route_Site_115_0 ---  1.0
# TP Route_Site_118_0 ---  20.0
# TP Route_Site_119_0 ---  105.0
# TP Route_Site_120_0 ---  104.0
# TP Route_Site_121_0 ---  121.0
# TP Route_Site_122_0 ---  177.0
# TP Route_Site_123_0 ---  129.0
# TP Route_Site_124_0 ---  146.0
# TP Route_Site_125_0 ---  143.0
# TP Route_Site_126_0 ---  175.0
# TP Route_Site_127_0 ---  153.0
# TP Route_Site_128_0 ---  145.0
# TP Route_Site_129_0 ---  171.0
# TP Route_Site_130_0 ---  177.0
# TP Route_Site_131_0 ---  190.0
# TP Route_Site_132_0 ---  131.0
# TP Route_Site_133_0 ---  117.0
# TP Route_Site_134_0 ---  31.0
# TP Route_Site_135_0 ---  68.0
# TP Route_Site_136_0 ---  39.0
# TP Route_Site_137_0 ---  5.0
# TP Route_Site_138_0 ---  33.0
# TP Route_Site_139_0 ---  47.0
# TP Route_Site_140_0 ---  8.0
# TP Route_Site_141_0 ---  1.0
# TP Route_Site_142_0 ---  1.0
# TP Route_Site_143_0 ---  32.0
# TP Route_Site_144_0 ---  111.0
# TP Route_Site_145_0 ---  152.0
# TP Route_Site_146_0 ---  135.0
# TP Route_Site_147_0 ---  169.0
# TP Route_Site_148_0 ---  98.0
# TP Route_Site_149_0 ---  177.0
# TP Route_Site_150_0 ---  183.0
# TP Route_Site_151_0 ---  149.0
# TP Route_Site_152_0 ---  100.0
# TP Route_Site_153_0 ---  146.0
# TP Route_Site_154_0 ---  181.0
# TP Route_Site_155_0 ---  169.0
# TP Route_Site_156_0 ---  182.0
# TP Route_Site_157_0 ---  209.0
# TP Route_Site_158_0 ---  143.0
# TP Route_Site_159_0 ---  115.0
# TP Route_Site_160_0 ---  67.0
# TP Route_Site_161_0 ---  17.0
# TP Route_Site_162_0 ---  11.0
# TP Route_Site_163_0 ---  104.0
# TP Route_Site_164_0 ---  229.0
# TP Route_Site_165_0 ---  61.0
# TP Route_Site_166_0 ---  18.0
# TP Route_Site_169_0 ---  13.0
# TP Route_Site_170_0 ---  56.0
# TP Route_Site_171_0 ---  76.0
# TP Route_Site_172_0 ---  95.0
# TP Route_Site_173_0 ---  129.0
# TP Route_Site_174_0 ---  157.0
# TP Route_Site_175_0 ---  150.0
# TP Route_Site_176_0 ---  142.0
# TP Route_Site_177_0 ---  134.0
# TP Route_Site_178_0 ---  135.0
# TP Route_Site_179_0 ---  154.0
# TP Route_Site_180_0 ---  262.0
# TP Route_Site_181_0 ---  203.0
# TP Route_Site_182_0 ---  112.0
# TP Route_Site_183_0 ---  136.0
# TP Route_Site_184_0 ---  112.0
# TP Route_Site_185_0 ---  87.0
# TP Route_Site_186_0 ---  106.0
# TP Route_Site_187_0 ---  52.0
# TP Route_Site_188_0 ---  8.0
# TP Route_Site_189_0 ---  65.0
# TP Route_Site_190_0 ---  180.0
# TP Route_Site_191_0 ---  146.0
# TP Route_Site_192_0 ---  60.0
# TP Route_Site_193_0 ---  19.0
# TP Route_Site_194_0 ---  2.0
# TP Route_Site_195_0 ---  3.0
# TP Route_Site_197_0 ---  1.0
# TP Route_Site_198_0 ---  4.0
# TP Route_Site_199_0 ---  6.0
# TP Route_Site_200_0 ---  20.0
# TP Route_Site_201_0 ---  20.0
# TP Route_Site_202_0 ---  13.0
# TP Route_Site_207_0 ---  2.0
# TP Route_Site_208_0 ---  74.0
# TP Route_Site_209_0 ---  74.0
# TP Route_Site_210_0 ---  85.0
# TP Route_Site_211_0 ---  109.0
# TP Route_Site_212_0 ---  255.0
# TP Route_Site_213_0 ---  177.0
# TP Route_Site_214_0 ---  166.0
# TP Route_Site_215_0 ---  83.0
# TP Route_Site_216_0 ---  217.0
# TP Route_Site_217_0 ---  189.0
# TP Route_Site_218_0 ---  194.0
# TP Route_Site_219_0 ---  273.0
# TP Route_Site_220_0 ---  187.0
# TP Route_Site_221_0 ---  164.0
# TP Route_Site_222_0 ---  143.0
# TP Route_Site_223_0 ---  158.0
# TP Route_Site_224_0 ---  200.0
# TP Route_Site_225_0 ---  308.0
# TP Route_Site_226_0 ---  123.0
# TP Route_Site_227_0 ---  95.0
# TP Route_Site_228_0 ---  154.0
# TP Route_Site_229_0 ---  276.0
# TP Route_Site_230_0 ---  301.0
# TP Route_Site_231_0 ---  89.0
# TP Route_Site_232_0 ---  16.0
# TP Route_Site_233_0 ---  28.0
# TP Route_Site_234_0 ---  35.0
# TP Route_Site_235_0 ---  1.0
# TP Route_Site_236_0 ---  23.0
# TP Route_Site_237_0 ---  45.0
# TP Route_Site_238_0 ---  25.0
# TP Route_Site_239_0 ---  14.0
# TP Route_Site_240_0 ---  20.0
# TP Route_Site_241_0 ---  98.0
# TP Route_Site_242_0 ---  108.0
# TP Route_Site_243_0 ---  22.0
# TP Route_Site_244_0 ---  10.0
# TP Route_Site_246_0 ---  6.0
# TP Route_Site_247_0 ---  5.0
# TP Route_Site_248_0 ---  23.0
# TP Route_Site_249_0 ---  111.0
# TP Route_Site_250_0 ---  73.0
# TP Route_Site_251_0 ---  98.0
# TP Route_Site_252_0 ---  245.0
# TP Route_Site_253_0 ---  314.0
# TP Route_Site_254_0 ---  241.0
# TP Route_Site_255_0 ---  114.0
# TP Route_Site_256_0 ---  162.0
# TP Route_Site_257_0 ---  220.0
# TP Route_Site_258_0 ---  201.0
# TP Route_Site_259_0 ---  211.0
# TP Route_Site_260_0 ---  248.0
# TP Route_Site_261_0 ---  272.0
# TP Route_Site_262_0 ---  215.0
# TP Route_Site_263_0 ---  170.0
# TP Route_Site_264_0 ---  150.0
# TP Route_Site_265_0 ---  191.0
# TP Route_Site_266_0 ---  244.0
# TP Route_Site_267_0 ---  170.0
# TP Route_Site_268_0 ---  222.0
# TP Route_Site_269_0 ---  236.0
# TP Route_Site_270_0 ---  192.0
# TP Route_Site_271_1 ---  221.0
# TP Route_Site_272_0 ---  146.0
# TP Route_Site_273_1 ---  37.0
# TP Route_Site_274_1 ---  74.0
# TP Route_Site_275_0 ---  8.0
# TP Route_Site_277_0 ---  5.0
# TP Route_Site_278_1 ---  37.0
# TP Route_Site_279_1 ---  3.0
# TP Route_Site_282_1 ---  9.0
# TP Route_Site_283_1 ---  42.0
# TP Route_Site_284_1 ---  15.0
# TP Route_Site_285_0 ---  2.0
# TP Route_Site_286_1 ---  9.0
# TP Route_Site_287_1 ---  24.0
# TP Route_Site_288_1 ---  12.0
# TP Route_Site_289_1 ---  56.0
# TP Route_Site_290_1 ---  12.0
# TP Route_Site_291_1 ---  42.0
# TP Route_Site_292_1 ---  120.0
# TP Route_Site_293_1 ---  234.0
# TP Route_Site_294_1 ---  236.0
# TP Route_Site_295_1 ---  241.0
# TP Route_Site_296_1 ---  336.0
# TP Route_Site_297_1 ---  240.0
# TP Route_Site_298_1 ---  337.0
# TP Route_Site_299_1 ---  345.0

# %%
from pulp import *
import random as rnd

sites = [f"Site_{i}" for i in range(100)]
depots = [f"{i}" for i in range(100)]

supply = {f"Site_{i}":arr[i] for i in range(100)}
supply_2019 = {f"Site_{i}":arr[i] for i in range(100)}

refineries = [f"{i}" for i in range(100)]

demand = {f"{i}":19999.99 for i in range(100)}
demand_ref = {f"{i}":99999.99 for i in range(100)}

sad = [list(i) for i in list(dist.values)]
distance = sad
distance = makeDict([sites, depots], distance, 0)

prob = LpProblem("Depot_Problem", LpMinimize)

Routes = [(w, b) for w in sites for b in depots]

depot_var = LpVariable.dicts("Supply_to_depots",depots, 0, 1, LpInteger)

vars = LpVariable.dicts("Route", (sites, depots), 0, None, LpInteger)

# Ref
ref_vars = LpVariable.dicts("Route_ref", (depots, refineries), 0, None, LpInteger)
ref_var = LpVariable.dicts("Supply_to_refineries",refineries, 0, 1, LpInteger)
Routes_ref = [(w, b) for w in depots for b in refineries]

main_obj = (lpSum(vars[w][b] * distance[w][b] for (w, b) in Routes)*0.001)
ref_constraint = lpSum(ref_vars[b][k] * distance[b][k] for (b, k) in Routes_ref)*0.001

prob += ref_constraint + main_obj

for w in sites:
    prob += (
        lpSum(vars[w][b] for b in depots) <= supply[w],
        f"Sites must not give more than they produce{w}"
    )

#Refineries
for b in depots:
    prob += (
        lpSum(ref_vars[b][k] for k in refineries) <= (lpSum(vars[w][b] for w in sites)),
        f"Depot must not give more than they produce{b}"
    )

for b in depots:
    prob += (
        lpSum([vars[w][b] for w in sites]) <= demand[b]*depot_var[b],
        f"Sum of products into depot should be less than its capacity {b}"
    )

#Refineries
for b in refineries:
    prob += (
        lpSum([ref_vars[j][b] for j in depots]) <= demand_ref[b]*ref_var[b],
        f"Sum of products into refineries should be less than its capacity {b}"
    )

prob += lpSum(depot_var[b] for b in depots) <= max(1, min(25,(0.8*sum(supply.values())//20000)+1))
prob += lpSum(ref_var[b] for b in refineries) <= max(1, min(5,(0.8*sum(supply.values())//100000)+1))

huf = ()
for w in sites:
    for b in depots:
        if depot_var[b] >= 1:
            huf += (
            lpSum(vars[w][b] )
            )

prob += lpSum(huf) >= sum(supply.values())*0.8

# Contraint 8: Amount entering into depot equals amount exiting depot
for b in depots:
    if depot_var[b] >= 1:
        prob += (
            lpSum(vars[w][b] for w in sites) <= lpSum(ref_vars[b][k] for k in refineries if ref_var[k] >= 1)
        )
    
# Refineries
hufe = ()
for w in depots:
    for b in refineries:
        if ref_var[b] >= 1:
            hufe += (
            lpSum(ref_vars[w][b] )
            )

prob += lpSum(hufe) >= sum(supply.values())*0.8

solver_options = {'msg': True, 'timeLimit': 1500}  # Set solver-specific options
prob.solve(CPLEX_CMD(**solver_options))

# for i in vars:
#     for each in vars[i]:
#         if vars[i][each].varValue > 0:
#             print(f"TP {vars[i][each]} ---  {vars[i][each].varValue}")
# print("\nSupply ref ")
# for i in ref_vars:
#     for each in ref_vars[i]:
#         if ref_vars[i][each].varValue > 0:
#             print(f"TP {ref_vars[i][each]} ---  {ref_vars[i][each].varValue}")
            
print("Supplied Depots:")
for b in depots:
    if depot_var[b].varValue == 1:
        print(b)

print("\nSupplied Refineries:")
for b in refineries:
    if ref_var[b].varValue == 1:
        print(b)

print(f"\n{sum(supply.values())}")
print((sum(supply.values())//20000)+1)
print(sum([(lpSum(vars[w][b].varValue for w in sites)) for b in depots if depot_var[b].varValue >= 1]))
print(sum([(lpSum(ref_vars[w][b].varValue for w in depots)) for b in refineries if ref_var[b].varValue >= 1]))
# print([depot_var[i].varValue for i in depot_var if depot_var[i] == 1])
# print(supply.values())
