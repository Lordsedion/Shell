# %% [markdown]
# ### Cost = (Sum of distance from the 𝑖tℎ harvesting site to the 𝑗𝑡ℎ depot  X  The amount of biomass gotten and transported from the 𝑖𝑡ℎ harvesting site to the 𝑗𝑡ℎ depot)
# #    +
# ###      (Sum of distance from the 𝑖tℎ harvesting site to the 𝑗𝑡ℎ depot  X  The amount of pellets transported from the 𝑗𝑡ℎ depot to the 𝑘𝑡ℎ biorefinery)

# %%
import pandas as pd
import numpy as np
import heapq
from collections import Counter
import math
import random
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('pred.csv')
dataset_2019 = pd.read_csv('pred_2019.csv')
dist = pd.read_csv('dataset/Distance_Matrix.csv')
optDist = pd.read_csv('optimized_points.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
optDist.fillna(0, inplace=True)
distance_matrix = dist.values

# %%
arr = [i[0] for i in dataset.values]

# %%
dist = dist.drop(columns='Unnamed: 0')

# %%
totalArray = []
totArray = []
similarity_array = []
arr = [i[0] for i in dataset.values]

for index in range(2418):
    total,ind = 0,0
    distArr = [dist.values[index][i] for i in range(len(dist.values[index]))]
    distArr1 = [dist.values[index][i] for i in range(len(dist.values[index]))]
    
    distDict = {distArr[i]:i for i in range(len(distArr))}
    distArr.sort()
    
    d_arr = []
    tot = 0
    while total < 20000:
        d_arr.append(distDict[distArr[ind]])
        total += arr[distDict[distArr[ind]]]
        tot += distArr[ind]
        ind +=1
    similarity_array.append(d_arr)
    totalArray.append(total)
    totArray.append(tot)

# %%
def similar_array(arr1, arr2):
    count = 0
    for i in arr1:
        if i in arr2:
            count += 1
    if count > 0:
        return [count/len(arr1), count/len(arr2)]
    return -1

# %% [raw]
# optimize = []
# for i in range(len(similarity_array)):
#
#     optimize.append([])
#     for index in range(len(similarity_array)):
#         optimize[i].append(similar_array(similarity_array[i], similarity_array[index]))
#
#     if i%5 == 0:
#         print(f"Processing ... {(i/len(similarity_array))*100}")

# %% [raw]
# df = pd.DataFrame(optimize)
# df.to_csv('optimized_points.csv', index=False)
# df.head()

# %%
op1 = [list(i) for i in optDist.values]

# %%
def check_sum(array):
    summ = 0
    for i in array:
        summ += arr[i]
    return summ

# %%
def merger(apple, gods):
    impotent = []
    for index in gods:
        if check_sum(apple[index]) < 13000:
            impotent.append(index)
    return impotent

# %%
def similar_array(arr1, arr2):
    count = 0
    for i in arr1:
        if i in arr2:
            count += 1
    if count > 0:
        return count/len(arr1)
    return -1

# %%
def binSearch(arr, target):
    left, right = 0, len(arr)-1
    f = -1
    while left <= right:
        mid = left + (right-left)//2
        
        if arr[mid] == target:
            break
        elif arr[mid] > target:
            right = mid - 1
        else:
            left = mid + 1
    
    if arr[mid] == target:
        return mid
    else:
        x, y = 0,0
        if mid-1 >= 0:
            x = arr[mid-1]
        if mid+1 <= len(arr)-1:
            y = arr[mid+1]
        if abs(target-arr[mid]) < abs(target-x) and abs(target-arr[mid]) < abs(target-y):
            return mid
        if abs(target-x) < abs(target-y):
            return mid-1
        else:
            return mid+1

# %%
optDist.values.shape
# Out:
# (2418, 2418)

# %%
trial = [i for i in range(len(arr))]
used = [i for i in arr]
minUserArray = []
depots = []
bestScores = []

count = 0
while len(depots) < 15:

    minCost = float('inf')
    minUser = {}
    best = -1

    
    for index, values in enumerate(trial):
        distance = {}
        for i in trial:
            if dist.values[i, index] in distance.keys():
                newDays = dist.values[i, index]+(random.randint(0,1000)/1000000)
                while newDays in distance.keys():
                    newDays = dist.values[i, index]+(random.randint(0,1000)/100000)
                distance[newDays] = i
            else:
                distance[dist.values[i, index]]= i

        user = {}
        sorted_distance = list(distance.keys())
        sorted_distance.sort()

        cost = 0   
        price = 0
        
        i = 0
        while cost < 20000 and i <= len(trial)-1:
            if (used[distance[sorted_distance[i]]] + cost) < 20000:

                if used[distance[sorted_distance[i]]] > 0:
                    cost += used[distance[sorted_distance[i]]]
                    price += used[distance[sorted_distance[i]]] * sorted_distance[i]
                    user[distance[sorted_distance[i]]] = used[distance[sorted_distance[i]]]

            else:
                poll = 20000 - cost

                if used[distance[sorted_distance[i]]] > 0:
                    cost += poll
                    price += (poll * sorted_distance[i])
                    user[distance[sorted_distance[i]]] = poll
            i+=1
            count += 1
            if count%50000 == 0:
                print(f"{count} Iterations... \n")

        if price < minCost:
            minCost = price
            minUser = user
            best = index

    for i in minUser:
        used[i] -= minUser[i]

    depots.append(best)
    minUserArray.append(minUser)
    bestScores.append(minCost)
    
    print(f"Depot Found {best}\n Price: {minCost} {sum(minUser.values())}\n")
# Out:
# 50000 Iterations...
#
# 100000 Iterations...
#
# 150000 Iterations...
#
# 200000 Iterations...
#
# 250000 Iterations...
#
# 300000 Iterations...
#
# Depot Found 985
#  Price: 575014.8502436967 20000.0
#
# 350000 Iterations...
#
# 400000 Iterations...
#
# 450000 Iterations...
#
# 500000 Iterations...
#
# 550000 Iterations...
#
# 600000 Iterations...
#
# 650000 Iterations...
#
# 700000 Iterations...
#
# Depot Found 1290
#  Price: 687683.860286241 20000.0
#
# 750000 Iterations...
#
# 800000 Iterations...
#
# 850000 Iterations...
#
# 900000 Iterations...
#
# 950000 Iterations...
#
# 1000000 Iterations...
#
# 1050000 Iterations...
#
# 1100000 Iterations...
#
# 1150000 Iterations...
#
# Depot Found 1860
#  Price: 729065.4590746206 20000.0
#
# 1200000 Iterations...
#
# 1250000 Iterations...
#
# 1300000 Iterations...
#
# 1350000 Iterations...
#
# 1400000 Iterations...
#
# 1450000 Iterations...
#
# 1500000 Iterations...
#
# 1550000 Iterations...
#
# Depot Found 1469
#  Price: 752190.9263980059 20000.0
#
# 1600000 Iterations...
#
# 1650000 Iterations...
#
# 1700000 Iterations...
#
# 1750000 Iterations...
#
# 1800000 Iterations...
#
# 1850000 Iterations...
#
# 1900000 Iterations...
#
# 1950000 Iterations...
#
# 2000000 Iterations...
#
# Depot Found 437
#  Price: 790336.9501563032 20000.0
#
# 2050000 Iterations...
#
# 2100000 Iterations...
#
# 2150000 Iterations...
#
# 2200000 Iterations...
#
# 2250000 Iterations...
#
# 2300000 Iterations...
#
# 2350000 Iterations...
#
# 2400000 Iterations...
#
# 2450000 Iterations...
#
# 2500000 Iterations...
#
# Depot Found 1718
#  Price: 857554.0159402197 20000.0
#
# 2550000 Iterations...
#
# 2600000 Iterations...
#
# 2650000 Iterations...
#
# 2700000 Iterations...
#
# 2750000 Iterations...
#
# 2800000 Iterations...
#
# 2850000 Iterations...
#
# 2900000 Iterations...
#
# 2950000 Iterations...
#
# 3000000 Iterations...
#
# 3050000 Iterations...
#
# Depot Found 868
#  Price: 865953.2380442104 20000.0
#
# 3100000 Iterations...
#
# 3150000 Iterations...
#
# 3200000 Iterations...
#
# 3250000 Iterations...
#
# 3300000 Iterations...
#
# 3350000 Iterations...
#
# 3400000 Iterations...
#
# 3450000 Iterations...
#
# 3500000 Iterations...
#
# 3550000 Iterations...
#
# 3600000 Iterations...
#
# 3650000 Iterations...
#
# Depot Found 1637
#  Price: 872824.6494116582 20000.0
#
# 3700000 Iterations...
#
# 3750000 Iterations...
#
# 3800000 Iterations...
#
# 3850000 Iterations...
#
# 3900000 Iterations...
#
# 3950000 Iterations...
#
# 4000000 Iterations...
#
# 4050000 Iterations...
#
# 4100000 Iterations...
#
# 4150000 Iterations...
#
# 4200000 Iterations...
#
# 4250000 Iterations...
#
# 4300000 Iterations...
#
# Depot Found 561
#  Price: 936020.608807715 20000.0
#
# 4350000 Iterations...
#
# 4400000 Iterations...
#
# 4450000 Iterations...
#
# 4500000 Iterations...
#
# 4550000 Iterations...
#
# 4600000 Iterations...
#
# 4650000 Iterations...
#
# 4700000 Iterations...
#
# 4750000 Iterations...
#
# 4800000 Iterations...
#
# 4850000 Iterations...
#
# 4900000 Iterations...
#
# 4950000 Iterations...
#
# 5000000 Iterations...
#
# 5050000 Iterations...
#
# 5100000 Iterations...
#
# Depot Found 149
#  Price: 1030146.1123289912 20000.0
#
# 5150000 Iterations...
#
# 5200000 Iterations...
#
# 5250000 Iterations...
#
# 5300000 Iterations...
#
# 5350000 Iterations...
#
# 5400000 Iterations...
#
# 5450000 Iterations...
#
# 5500000 Iterations...
#
# 5550000 Iterations...
#
# 5600000 Iterations...
#
# 5650000 Iterations...
#
# 5700000 Iterations...
#
# 5750000 Iterations...
#
# 5800000 Iterations...
#
# 5850000 Iterations...
#
# 5900000 Iterations...
#
# 5950000 Iterations...
#
# 6000000 Iterations...
#
# Depot Found 1983
#  Price: 1051023.9506431967 20000.0
#
# 6050000 Iterations...
#
# 6100000 Iterations...
#
# 6150000 Iterations...
#
# 6200000 Iterations...
#
# 6250000 Iterations...
#
# 6300000 Iterations...
#
# 6350000 Iterations...
#
# 6400000 Iterations...
#
# 6450000 Iterations...
#
# 6500000 Iterations...
#
# 6550000 Iterations...
#
# 6600000 Iterations...
#
# 6650000 Iterations...
#
# 6700000 Iterations...
#
# 6750000 Iterations...
#
# 6800000 Iterations...
#
# 6850000 Iterations...
#
# 6900000 Iterations...
#
# 6950000 Iterations...
#
# 7000000 Iterations...
#
# 7050000 Iterations...
#
# Depot Found 1432
#  Price: 1059105.7689196093 20000.0
#
# 7100000 Iterations...
#
# 7150000 Iterations...
#
# 7200000 Iterations...
#
# 7250000 Iterations...
#
# 7300000 Iterations...
#
# 7350000 Iterations...
#
# 7400000 Iterations...
#
# 7450000 Iterations...
#
# 7500000 Iterations...
#
# 7550000 Iterations...
#
# 7600000 Iterations...
#
# 7650000 Iterations...
#
# 7700000 Iterations...
#
# 7750000 Iterations...
#
# 7800000 Iterations...
#
# 7850000 Iterations...
#
# 7900000 Iterations...
#
# 7950000 Iterations...
#
# 8000000 Iterations...
#
# 8050000 Iterations...
#
# 8100000 Iterations...
#
# 8150000 Iterations...
#
# 8200000 Iterations...
#
# 8250000 Iterations...
#
# 8300000 Iterations...
#
# Depot Found 1254
#  Price: 1310763.3406116494 20000.0
#
# 8350000 Iterations...
#
# 8400000 Iterations...
#
# 8450000 Iterations...
#
# 8500000 Iterations...
#
# 8550000 Iterations...
#
# 8600000 Iterations...
#
# 8650000 Iterations...
#
# 8700000 Iterations...
#
# 8750000 Iterations...
#
# 8800000 Iterations...
#
# 8850000 Iterations...
#
# 8900000 Iterations...
#
# 8950000 Iterations...
#
# 9000000 Iterations...
#
# 9050000 Iterations...
#
# 9100000 Iterations...
#
# 9150000 Iterations...
#
# 9200000 Iterations...
#
# 9250000 Iterations...
#
# 9300000 Iterations...
#
# 9350000 Iterations...
#
# 9400000 Iterations...
#
# 9450000 Iterations...
#
# 9500000 Iterations...
#
# 9550000 Iterations...
#
# 9600000 Iterations...
#
# 9650000 Iterations...
#
# 9700000 Iterations...
#
# 9750000 Iterations...
#
# 9800000 Iterations...
#
# 9850000 Iterations...
#
# 9900000 Iterations...
#
# Depot Found 2187
#  Price: 1375238.9316689677 20000.0
#
# 9950000 Iterations...
#
# 10000000 Iterations...
#
# 10050000 Iterations...
#
# 10100000 Iterations...
#
# 10150000 Iterations...
#
# 10200000 Iterations...
#
# 10250000 Iterations...
#
# 10300000 Iterations...
#
# 10350000 Iterations...
#
# 10400000 Iterations...
#
# 10450000 Iterations...
#
# 10500000 Iterations...
#
# 10550000 Iterations...
#
# 10600000 Iterations...
#
# 10650000 Iterations...
#
# 10700000 Iterations...
#
# 10750000 Iterations...
#
# 10800000 Iterations...
#
# 10850000 Iterations...
#
# 10900000 Iterations...
#
# 10950000 Iterations...
#
# 11000000 Iterations...
#
# 11050000 Iterations...
#
# 11100000 Iterations...
#
# 11150000 Iterations...
#
# 11200000 Iterations...
#
# 11250000 Iterations...
#
# 11300000 Iterations...
#
# 11350000 Iterations...
#
# 11400000 Iterations...
#
# 11450000 Iterations...
#
# 11500000 Iterations...
#
# 11550000 Iterations...
#
# 11600000 Iterations...
#
# 11650000 Iterations...
#
# 11700000 Iterations...
#
# 11750000 Iterations...
#
# 11800000 Iterations...
#
# 11850000 Iterations...
#
# Depot Found 1004
#  Price: 1509059.8398407577 20000.0

# %%
print(depots)
# Out:
# [985, 1290, 1860, 1469, 437, 1718, 868, 1637, 561, 149, 1983, 1432, 1254, 2187, 1004]

# %%
sum(minUserArray[5].values())
# Out:
# 20000.0

# %%
sum(bestScores)*0.001
# Out:
# 14401.982502375842

# %%
trial_refineries = [i for i in depots]
trial = [i for i in range(len(arr))]

used1 = {}
for i,j in enumerate(minUserArray):
    used1[trial_refineries[i]] = sum([i for i in minUserArray[i].values()])

minRefArray = []
refineries = []
bestScoreRefineries = []

while len(refineries) < 3:

    minCost = float('inf')
    minUser = {}
    best = -1

    count = 0
    for index, values in enumerate(trial):
        distance = {}
        for i in trial_refineries:
            if dist.values[i, index] in distance.keys():
                newDays = dist.values[i, index]+(random.randint(0,1000)/1000000)
                while newDays in distance.keys():
                    newDays = dist.values[i, index]+(random.randint(0,1000)/100000)
                distance[newDays] = i
            else:
                distance[dist.values[i, index]]= i

        user = {}
        sorted_distance = list(distance.keys())
        sorted_distance.sort()

        cost = 0   
        price = 0
        
        i = 0
        while cost < 100000 and i <= len(trial_refineries)-2:
            if (used1[distance[sorted_distance[i]]] + cost) < 100000:

                if used1[distance[sorted_distance[i]]] > 0:
                    cost += used1[distance[sorted_distance[i]]]
                    price += used1[distance[sorted_distance[i]]] * sorted_distance[i]
                    user[distance[sorted_distance[i]]] = used1[distance[sorted_distance[i]]]

            else:
                poll = 100000 - cost

                if used1[distance[sorted_distance[i]]] > 0:
                    cost += poll
                    price += (poll * sorted_distance[i])
                    user[distance[sorted_distance[i]]] = poll
            i+=1
            count += 1
            if count%50000 == 0:
                print(f"{count} Iterations... \n")

        if price < minCost:
            minCost = price
            minUser = user
            best = index

    for i in minUser:
        used1[i] -= minUser[i]

    refineries.append(best)
    minRefArray.append(minUser)
    bestScoreRefineries.append(minCost)
    
    print(f"Depot Found {best}\n Price: {minCost}\n")
# Out:
# Depot Found 879
#  Price: 7859399.981909329
#
# Depot Found 1461
#  Price: 8935606.186015636
#
# Depot Found 1281
#  Price: 14816377.375409624

# %%
sum(bestScoreRefineries)*0.001
# Out:
# 31536.485246271655

# %% [markdown]
# ### 2019 Analysis arrangement.

# %%
print([dict(i) for i in minUserArray])
# Out:
# [{985: 107.06365447840004, 984: 439.522866369, 923: 579.6367407130003, 986: 86.96499862680002, 1039: 499.13322936300005, 924: 485.1639010569998, 922: 791.154634387, 1040: 284.3644114679999, 983: 715.2706085109994, 1041: 85.5393308255, 921: 818.7851763839997, 1038: 418.007350931, 861: 649.312549427, 925: 173.8179801958999, 860: 579.8881121730003, 1094: 496.565402212, 859: 698.6975915389997, 1042: 182.91551292799988, 1095: 182.061149675, 1093: 510.77795653400005, 1092: 441.0723403949999, 982: 237.19956244999983, 987: 213.38270583799996, 858: 824.6910351469998, 862: 760.1786633229998, 796: 746.5594055109997, 920: 485.3955245910002, 988: 225.08034652299995, 1037: 231.183207467, 1096: 209.4771957389999, 1150: 185.215263902, 926: 197.5897486869999, 1149: 400.830046089, 1043: 114.4337586158, 1148: 493.856121817, 795: 403.09362518900014, 856: 10.77398981205, 1091: 255.53516059999995, 728: 120.19622024589997, 792: 184.51805022899995, 729: 78.55891441359998, 1151: 221.68292220699996, 730: 161
# %%
arr1 = [i[0] for i in dataset_2019.values]

minUserArray_2019 = [dict(i) for i in minUserArray]
minRefArray_2019 = [i for i in minRefArray]

for dictionary in minUserArray_2019:
    for key in dictionary:
        dictionary[key] = 0
        
for dictionary in minRefArray_2019:
    for key in dictionary:
        dictionary[key] = 0

for index, value in enumerate(minUserArray_2019):
    cost = 0
    for each in minUserArray_2019[index]:
        if (cost + arr1[each]) < 20000:
            minUserArray_2019[index][each] = arr1[each]
            cost += arr1[each]
        else:
            minUserArray_2019[index][each] = 20000 - cost
            cost += (20000 - cost)
            
for index, value in enumerate(minUserArray):
    cost = 0
    for each in minUserArray[index]:
        if (cost + arr[each]) < 20000:
            minUserArray[index][each] = arr[each]
            cost += arr[each]
        else:
            minUserArray[index][each] = 20000 - cost
            cost += (20000 - cost)
            
###############################################
###############################################
###############################################

minRefArray_2019 = [dict(i) for i in minRefArray]

for index, value in enumerate(minRefArray_2019):
    cost = 0
    for ind, each in enumerate(minRefArray_2019[index]):
        if cost + [sum(i.values()) for i in minUserArray_2019][ind] < 100000:
            minRefArray_2019[index][each] = [sum(i.values()) for i in minUserArray_2019][ind]
            cost += arr1[each]
        else:
            minRefArray_2019[index][each] = 100000 - cost
            cost += 100000 - cost
            
minRefArray = [dict(i) for i in minRefArray]

for dictionary in minRefArray:
    for key in dictionary:
        dictionary[key] = 0

for index, value in enumerate(minRefArray):
    cost = 0
    for ind, each in enumerate(minRefArray[index]):
        if cost + [sum(i.values()) for i in minUserArray][ind] < 100000:
            minRefArray[index][each] = [sum(i.values()) for i in minUserArray][ind]
            cost += arr1[each]
        else:
            minRefArray[index][each] = 100000 - cost
            cost += 100000 - cost

# %%
[sum(i.values()) for i in minUserArray]
# Out:
# [20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20000.0]

# %%
print(minRefArray)
# Out:
# [{1004: 20000.0, 437: 20000.0, 561: 20000.0, 868: 20000.0, 1290: 20000.0}, {1637: 20000.0, 1469: 20000.0, 985: 20000.0, 1860: 20000.0, 1254: 20000.0}, {1290: 20000.0, 1983: 20000.0, 1718: 20000.0, 1432: 20000.0, 149: 20000.0, 1254: 20000.0}]

# %% [raw]
# arr = [i[0] for i in dataset.values]
#
# minUserArray = [dict(i) for i in minUserArray]
#
# for index, value in enumerate(minUserArray):
#     cost = 0
#     for each in minUserArray[index]:
#         if cost + minUserArray[index][each] < 20000:
#             minUserArray[index][each] = arr[each]
#             cost += arr[each]
#         else:
#             minUserArray[index][each] = 20000 - cost
#             cost += 20000 - cost

# %%
arr[3]
# Out:
# 94.52198760620004

# %%
##############################################################################
over_all_depots = {}
over_all_value = {}

for i in range(len(minUserArray)):
    for j in minUserArray[i]:
        newDay = j
        while newDay in over_all_depots.keys():
            newDay = j+(random.randint(1,9)/random.randint(99999, 111111))
        over_all_depots[newDay] = depots[i]
        over_all_value[newDay] = minUserArray[i][j]
        
used_me = [i for i in over_all_depots]
used_me.sort()

over_all_ref = {}
over_all_value1 = []
ref_loc = []

for i in range(len(minRefArray)):
    for j in minRefArray[i]:
        newDay = j
        while newDay in over_all_ref.keys():
            newDay = j+(random.randint(1,9)/random.randint(99999, 111111))
        over_all_ref[newDay] = refineries[i]
        over_all_value1.append(minRefArray[i][j])
        ref_loc.append(refineries[i])
        
used_me1 = [i for i in over_all_ref]
used_me1.sort()

###############################################  2019  #######################################################
##############################################################################################################

over_all_depots_2019 = {}
over_all_value_2019 = {}

for i in range(len(minUserArray_2019)):
    for j in minUserArray_2019[i]:
        newDay = j
        while newDay in over_all_depots_2019.keys():
            newDay = j+(random.randint(1,9)/random.randint(99999, 111111))
        over_all_depots_2019[newDay] = depots[i]
        over_all_value_2019[newDay] = minUserArray_2019[i][j]
        
used_me_2019 = [i for i in over_all_depots_2019]
used_me_2019.sort()

over_all_ref_2019 = {}
over_all_value1_2019 = []
ref_loc_2019 = []

for i in range(len(minRefArray_2019)):
    for j in minRefArray_2019[i]:
        newDay = j
        while newDay in over_all_ref_2019.keys():
            newDay = j+(random.randint(1,9)/random.randint(99999, 111111))
        over_all_ref_2019[newDay] = refineries[i]
        over_all_value1_2019.append(minRefArray_2019[i][j])
        ref_loc_2019.append(refineries[i])
        
used_me1_2019 = [i for i in over_all_ref_2019]
used_me1_2019.sort()


#####################################################################################################
#####################################################################################################
bro = {i:[] for i in ['year', 'data_type', 'source_index','destination_index','value']}

bro['year'].extend(['20182019']*(len(depots)+len(refineries)))
bro['data_type'].extend(['depot_location']*len(depots))
bro['data_type'].extend(['refinery_location']*len(refineries))
bro['source_index'].extend([i for i in depots])
bro['source_index'].extend([i for i in refineries])
bro['destination_index'].extend([0 for i in range(len(depots)+ len(refineries))])
bro['value'].extend([0 for i in range(len(depots)+ len(refineries))])

##################################### ForeCast Section Here ########################################
bro['year'].extend(['2018']* len(dataset))
bro['data_type'].extend(['biomass_forecast']* len(dataset))
bro['source_index'].extend([i for i in range(len(dataset))])
bro['destination_index'].extend([0 for i in range(len(dataset))])
bro['value'].extend([i[0] for i in dataset.values])

bro['year'].extend(['2018' for i in over_all_depots])
bro['data_type'].extend(['biomass_demand_supply' for i in over_all_depots])
bro['source_index'].extend([i for i in used_me])
bro['destination_index'].extend([i for i in over_all_depots.values()])
bro['value'].extend([over_all_value[i] for i in used_me])


############################################################

bro['year'].extend(['2018' for i in over_all_ref])
bro['data_type'].extend(['pellet_demand_supply' for i in over_all_ref])
bro['source_index'].extend([i for i in used_me1])
bro['destination_index'].extend([i for i in ref_loc])
bro['value'].extend([i for i in over_all_value1])


################################## 2019 ForeCast #############################
##############################################################################


bro['year'].extend(['2019']* len(dataset_2019))
bro['data_type'].extend(['biomass_forecast']* len(dataset_2019))
bro['source_index'].extend([i for i in range(len(dataset_2019))])
bro['destination_index'].extend([0 for i in range(len(dataset_2019))])
bro['value'].extend([i[0] for i in dataset_2019.values])

bro['year'].extend(['2019' for i in over_all_depots_2019])
bro['data_type'].extend(['biomass_demand_supply' for i in over_all_depots_2019])
bro['source_index'].extend([i for i in used_me_2019])
bro['destination_index'].extend([i for i in over_all_depots_2019.values()])
bro['value'].extend([over_all_value_2019[i] for i in used_me_2019])

bro['year'].extend(['2019' for i in over_all_ref_2019])
bro['data_type'].extend(['pellet_demand_supply' for i in over_all_ref_2019])
bro['source_index'].extend([i for i in used_me1_2019])
bro['destination_index'].extend([i for i in ref_loc_2019])
bro['value'].extend([i for i in over_all_value1_2019])

############################################################

# keys = [len(i) for i in bro.values()]

# for i in bro:
#     if len(bro[i]) < max(keys):
#         bro[i].extend([-1 for i in range(max(keys)-len(bro[i]))])

# %%
df = pd.DataFrame(bro)
df
# Out:
#           year              data_type  source_index  destination_index  \
# 0     20182019         depot_location    985.000000                  0
# 1     20182019         depot_location   1290.000000                  0
# 2     20182019         depot_location   1860.000000                  0
# 3     20182019         depot_location   1469.000000                  0
# 4     20182019         depot_location    437.000000                  0
# 5     20182019         depot_location   1718.000000                  0
# 6     20182019         depot_location    868.000000                  0
# 7     20182019         depot_location   1637.000000                  0
# 8     20182019         depot_location    561.000000                  0
# 9     20182019         depot_location    149.000000                  0
# 10    20182019         depot_location   1983.000000                  0
# 11    20182019         depot_location   1432.000000                  0
# 12    20182019         depot_location   1254.000000                  0
# 13    20182019         depot_location   2187.000000                  0
# 14    20182019         depot_location   1004.000000                  0
# 15    20182019      refinery_location    879.000000                  0
# 16    20182019      refinery_location   1461.000000                  0
# 17    20182019      refinery_location   1281.000000                  0
# 18        2018       biomass_forecast      0.000000                  0
# 19        2018       biomass_forecast      1.000000                  0
# 20        2018       biomass_forecast      2.000000                  0
# 21        2018       biomass_forecast      3.000000                  0
# 22        2018       biomass_forecast      4.000000                  0
# 23        2018       biomass_forecast      5.000000                  0
# 24        2018       biomass_forecast      6.000000                  0
# 25        2018       biomass_forecast      7.000000                  0
# 26        2018       biomass_forecast      8.000000                  0
# 27        2018       biomass_forecast      9.000000                  0
# 28        2018       biomass_forecast     10.000000                  0
# 29        2018       biomass_forecast     11.000000                  0
# 30        2018       biomass_forecast     12.000000                  0
# 31        2018       biomass_forecast     13.000000                  0
# 32        2018       biomass_forecast     14.000000                  0
# 33        2018       biomass_forecast     15.000000                  0
# 34        2018       biomass_forecast     16.000000                  0
# 35        2018       biomass_forecast     17.000000                  0
# 36        2018       biomass_forecast     18.000000                  0
# 37        2018       biomass_forecast     19.000000                  0
# 38        2018       biomass_forecast     20.000000                  0
# 39        2018       biomass_forecast     21.000000                  0
# 40        2018       biomass_forecast     22.000000                  0
# 41        2018       biomass_forecast     23.000000                  0
# 42        2018       biomass_forecast     24.000000                  0
# 43        2018       biomass_forecast     25.000000                  0
# 44        2018       biomass_forecast     26.000000                  0
# 45        2018       biomass_forecast     27.000000                  0
# 46        2018       biomass_forecast     28.000000                  0
# 47        2018       biomass_forecast     29.000000                  0
# 48        2018       biomass_forecast     30.000000                  0
# 49        2018       biomass_forecast     31.000000                  0
# 50        2018       biomass_forecast     32.000000                  0
# 51        2018       biomass_forecast     33.000000                  0
# 52        2018       biomass_forecast     34.000000                  0
# 53        2018       biomass_forecast     35.000000                  0
