# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.preprocessing import MinMaxScaler, QuantileTransformer
from sklearn.preprocessing import RobustScaler, PowerTransformer
from sklearn.preprocessing import StandardScaler, MaxAbsScaler

from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.feature_selection import RFE

import pandas as pd
import seaborn as sns
import random as rnd
import math

# %%
dataset = pd.read_csv('dataset/Biomass_History.csv')
print(len(dataset))
# dataset = dataset.drop(columns="Index")
dataset[:10]

color_pal = sns.color_palette()
# Out:
# 2418

# %%
sns.boxplot(data=dataset[:100], x='Longitude', y='2017', color='b')
# sns.boxplot(data=dataset[:1000], x='Latitude', y='2017', color='r')
# Out:
# <AxesSubplot: xlabel='Longitude', ylabel='2017'>

# %%
dataset = dataset.set_index(['Latitude', 'Longitude', 'Index'])

# %%
dataset.head()
# Out:
#                                2010       2011       2012       2013  \
# Latitude Longitude Index
# 24.66818 71.33144  0       8.475744   8.868568   9.202181   6.023070
#          71.41106  1      24.029778  28.551348  25.866415  21.634459
#          71.49069  2      44.831635  66.111168  56.982258  53.003735
#          71.57031  3      59.974419  80.821304  78.956543  63.160561
#          71.64994  4      14.653370  19.327524  21.928144  17.899586
#
#                                2014       2015       2016        2017
# Latitude Longitude Index
# 24.66818 71.33144  0      10.788374   6.647325   7.387925    5.180296
#          71.41106  1      34.419411  27.361908  40.431847   42.126945
#          71.49069  2      70.917908  42.517117  59.181629   73.203232
#          71.57031  3      93.513924  70.203171  74.536720  101.067352
#          71.64994  4      19.534035  19.165791  16.531315   26.086885

# %%
dataset.plot(style='.',
             figsize=(15,15),
             color=[color_pal[i] for i in range(len(dataset.columns))],
             title='BioWaste Spatial Locations')
# Out:
# <AxesSubplot: title={'center': 'BioWaste Spatial Locations'}, xlabel='Latitude,Longitude,Index'>

# %%
train = dataset[['2010', '2011', '2012', '2013', '2014', '2015', '2016']]
test = dataset[[ '2016']]

# %%
fig, ax = plt.subplots(figsize=(15,15))
train.plot(ax=ax, label='Training set', color=color_pal[0])
test.plot(ax=ax, label='Test set', color=color_pal[1])
# Out:
# <AxesSubplot: xlabel='Latitude,Longitude,Index'>

# %%
rainfall = {'2010': 368.61, '2011': 429.95, '2012': 281.61, '2013':318.21, '2014':266.87, '2015':293.29, '2016':218.95, '2017':439.01}

# %%
sns.heatmap(dataset.corr())
# Out:
# <AxesSubplot: >

# %%
df = dataset[0:].drop(columns=['2017','2016'])

# df['2018'] = y_pred
df['mean'] = 2
arr = [np.mean(df.iloc[i]) for i in range(len(df))]
for i in range(len(df)):
    df['mean'][i] = arr[i] 
    
# df['max'] = 2
# arr = [np.mean([max(df.iloc[i]),np.mean(df.iloc[i])]) for i in range(len(df))]
# for i in range(len(df)):
#     df['max'][i] = arr[i] 
    
# df['std'] = 2
# arr = [np.std(df.iloc[i]) for i in range(len(df))]
# for i in range(len(df)):
#     df['std'][i] = arr[i]

# df['rainfall 2011'] = 528.183/100
# df['rainfall 2012'] = 427.98/100
# df['rainfall 2013'] = 372.183/100
# df['rainfall 2014'] = 301.21/100
# df['rainfall 2015'] = 270.75/100
# df['rainfall 2016'] = 248.96/100
# df['temperature 2016'] = 41.82/100
# df['temperature 2015'] = 42/100

df[:20]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4860\1307091939.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean'][i] = arr[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_4860\1307091939.py:7: FutureWarning: Treating integers as positional in Series.__setitem__ with a Float64Index is deprecated. In a future version, `series[an_int] = val` will insert a new key into the Series. Use `series.iloc[an_int] = val` to treat the key as positional.
#   df['mean'][i] = arr[i]
#                                 2010        2011        2012        2013  \
# Latitude Longitude Index
# 24.66818 71.33144  0        8.475744    8.868568    9.202181    6.023070
#          71.41106  1       24.029778   28.551348   25.866415   21.634459
#          71.49069  2       44.831635   66.111168   56.982258   53.003735
#          71.57031  3       59.974419   80.821304   78.956543   63.160561
#          71.64994  4       14.653370   19.327524   21.928144   17.899586
#          71.72956  5       17.416639   35.811001   26.003826   27.348482
#          71.80919  6       23.568657   37.371216   38.298550   27.838022
#          71.88882  7       48.345234   91.215836   91.906342   41.121754
#          71.96844  8       58.784283   50.206898   60.707321   37.598999
#          72.04807  9       67.907379   68.375999   87.026680   54.602242
#          72.12769  10       8.916524   16.679886   21.618805   13.550439
#          72.20732  11       3.416374    2.891346    3.826416    3.098782
#          72.28694  12       2.298106    2.165051    1.780242    2.644897
#          72.36657  13       0.405264    0.146914    0.168368    0.251683
# 24.58758 71.25181  14       0.378064    1.557208    0.267738    0.703204
#          71.33144  15      45.174110   67.934845   58.226315   35.267220
#          71.41106  16      56.539742   83.333382   81.218788   59.407043
#          71.49069  17     139.388947  161.756607  149.984787  132.148621
#          71.57031  18     140.025986  143.676621  105.671814  105.944908
#          71.64994  19      51.762608   91.464401   90.009483   58.497116
#
#                                 2014        2015        mean
# Latitude Longitude Index
# 24.66818 71.33144  0       10.788374    6.647325    7.429323
#          71.41106  1       34.419411   27.361908   23.409045
#          71.49069  2       70.917908   42.517117   48.051974
#          71.57031  3       93.513924   70.203171   64.089989
#          71.64994  4       19.534035   19.165791   16.358350
#          71.72956  5       29.599268   22.026114   22.886476
#          71.80919  6       40.779961   32.014874   28.838754
#          71.88882  7       57.266411   60.263412   56.016998
#          71.96844  8       59.462139   38.788315   43.935422
#          72.04807  9       78.118126   44.796188   57.546659
#          72.12769  10      15.403367    7.133225   12.186035
#          72.20732  11       6.333014    4.840425    3.772337
#          72.28694  12       5.368379    4.423479    2.954308
#          72.36657  13       0.180468    0.131804    0.469215
# 24.58758 71.25181  14       0.319150    0.268468    0.784833
#          71.33144  15      55.589840   34.768570   42.708700
#          71.41106  16      85.440163   78.999176   63.848328
#          71.49069  17     205.142639  130.579208  131.571544
#          71.57031  18     175.587204  114.893639  112.542882
#          71.64994  19      83.193336   64.630905   63.079693

# %%
df1 = dataset[0:].drop(columns=['Latitude','2010','Longitude',])
df1['mean'] = 2

df1['2018'] = y_pred
arr1 = [np.mean(df1.iloc[i]) for i in range(len(df1))]
for i in range(len(df1)):
    df1['mean'][i] = arr1[i] 
    
df1['max'] = 2
arr = [np.mean([max(df.iloc[i]),np.mean(df.iloc[i])]) for i in range(len(df1))]
for i in range(len(df1)):
    df1['max'][i] = arr[i] 
        
# df1['std'] = 2
# arr = [np.std(df1.iloc[i]) for i in range(len(df1))]
# for i in range(len(df1)):
#     df1['std'][i] = arr[i]

# df1['rainfall 2012'] = 427.98/100
# df1['rainfall 2013'] = 372.183/100
# df1['rainfall 2014'] = 301.21/100
# df1['rainfall 2015'] = 270.75/100
# df1['rainfall 2016'] = 248.78/100
# df1['rainfall 2017'] = 409.82/100
# df1['temperature 2017'] = 43.82/100
# df1['temperature 2016'] = 41.82/100

df1.shape, df.shape
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\2111514268.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['mean'][i] = arr1[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\2111514268.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['max'][i] = arr[i]
# ((2418, 10), (2418, 10))

# %%
# sns.heatmap(df.corr())

# %%
df1[:3]
# Out:
#         2011       2012       2013       2014       2015       2016  \
# 0   8.868568   9.202181   6.023070  10.788374   6.647325   7.387925
# 1  28.551348  25.866415  21.634459  34.419411  27.361908  40.431847
# 2  66.111168  56.982258  53.003735  70.917908  42.517117  59.181629
#
#         2017       mean       2018        max
# 0   5.180296   7.089175   7.704834   9.330683
# 1  42.126945  28.113675  30.630747  36.391269
# 2  73.203232  53.574021  58.249147  65.675370

# %%
X = df.values
Y = df['mean'].values*1.1

# %%
# model = MLPRegressor(hidden_layer_sizes=(128,256), alpha=0.01, max_iter=35000, solver='lbfgs')
model = RandomForestRegressor(n_estimators=500, max_depth=500)

transforms = list()
transforms.append(('mms', MinMaxScaler()))
transforms.append(('ss', StandardScaler()))
# transforms.append(('asl', MaxAbsScaler()))
transforms.append(('rs', RobustScaler()))
transforms.append(('qt', QuantileTransformer(n_quantiles=50)))
transforms.append(('pw', PowerTransformer(method='yeo-johnson')))

fu = FeatureUnion(transforms)
# rfe = RFE(estimator=model, n_features_to_select=10)

steps = list()
steps.append(('fu', fu))
steps.append(('model', model))

pipeline = Pipeline(steps=steps)

# %%
pipeline.fit(X, Y)
# Out:
# Pipeline(steps=[('fu',
#                  FeatureUnion(transformer_list=[('mms', MinMaxScaler()),
#                                                 ('ss', StandardScaler()),
#                                                 ('rs', RobustScaler()),
#                                                 ('qt',
#                                                  QuantileTransformer(n_quantiles=50)),
#                                                 ('pw', PowerTransformer())])),
#                 ('model',
#                  RandomForestRegressor(max_depth=500, n_estimators=500))])

# %%
X_test = df1.values
X_test.shape, X.shape
# Out:
# ((2418, 10), (2418, 10))

# %%
y_test = df_joy['2017'].values

y_pred =  pipeline.predict(X_test)

print(f"Sum of Predicted: {sum(y_pred)}, Actual Sum :{sum(y_test)}")
# Out:
# Sum of Predicted: 361719.60835135437, Actual Sum :384857.0210760393

# %%
dad = 0

y_pred = [max(0, i) for i in y_pred]
for i in range(len(y_pred)):
    dad += abs(y_pred[i]-y_test[i])
dad
# Out:
# 81106.77488992934

# %%
# rd = MLPRegressor(hidden_layer_sizes=(128,256), alpha=0.025, max_iter=15000)
# rd = RandomForestRegressor()
# rd = GradientBoostingRegressor()

# rd.fit(X, Y)
# X_test = df1.values
# X_test.shape

# y_test = df_joy['2017'].values

# y_pred = rd.predict(X_test)
# sum(y_pred)

# %%
sum(y_test)

# %%
dad = 0
y_pred = rd.predict(X_test)
y_pred = [max(0, i) for i in y_pred]
for i in range(len(y_pred)):
    dad += abs(y_pred[i]-y_test[i])
dad

# %%
print(Y[0])

# %%
data = {
    "Predictions": y_pred
}

ds = pd.DataFrame(data)
ds[:50]
# Out:
#     Predictions
# 0      8.330731
# 1     33.653249
# 2     64.123463
# 3     85.258077
# 4     21.423087
# 5     31.257785
# 6     41.033814
# 7     67.602563
# 8     47.964857
# 9     64.054041
# 10    14.116222
# 11     5.268132
# 12     4.417585
# 13     0.337787
# 14     0.572085
# 15    46.816119
# 16    86.565348
# 17   161.027525
# 18   141.640853
# 19    81.937696
# 20   105.858173
# 21   117.311378
# 22   123.510910
# 23   141.806125
# 24   142.367017
# 25    70.334984
# 26    49.766115
# 27    37.843969
# 28     5.562637
# 29     0.391540
# 30    33.492354
# 31   104.744189
# 32   155.900251
# 33   138.462917
# 34   138.391834
# 35   130.674365
# 36   172.334053
# 37   162.645683
# 38   101.892464
# 39    74.042062
# 40    67.739036
# 41    88.476921
# 42   104.447705
# 43    31.265668
# 44     2.655719
# 45     0.383075
# 46     0.492473
# 47    21.465879
# 48    99.911960
# 49   114.717629

# %%
dataset[:50]

# %%
ds.to_csv('pred_u219.csv', index=False)
